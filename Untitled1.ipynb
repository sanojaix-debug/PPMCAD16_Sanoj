# %% [markdown]
# <a href="https://colab.research.google.com/github/sanojaix-debug/PPMCAD16_Sanoj/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number1=5
herovired=7

answer=number1+herovired
print(answer)
# Out:
# 12
